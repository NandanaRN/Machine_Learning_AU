# %%
import numpy as np
import matplotlib.pyplot as plt


x=np.array([1,2,3,4,5])
y=np.array([2,5,7,10,11])

x_mean= np.mean(x)
y_mean= np.mean(y)

numerator=np.sum((x-x_mean)*(y-y_mean))
denominator= np.sum((x-x_mean)**2)


w= numerator/denominator
b=y_mean-w*x_mean

# correct prediction
y_pred=w * x+b

print("slope (w):",w)
print("Intercept (b):",b)

plt.scatter(x, y)
plt.plot(x,y_pred, color='red')
plt.grid(True)
plt.show()
# Out:
# slope (w): 2.3
# Intercept (b): 0.10000000000000053

# %%
# homework problem
import numpy as np
import matplotlib.pyplot as plt


x=np.array([10,20,30,40,50])
y=np.array([12,15,19,31,43])

x_mean= np.mean(x)
y_mean= np.mean(y)

numerator=np.sum((x-x_mean)*(y-y_mean))
denominator= np.sum((x-x_mean)**2)


w= numerator/denominator
b=y_mean-w*x_mean

# correct prediction
y_pred=w * x+b

print("slope (w):",w)
print("Intercept (b):",b)

plt.scatter(x, y)
plt.plot(x,y_pred, color='red')
plt.grid(True)
plt.show()
# Out:
# slope (w): 0.78
# Intercept (b): 0.5999999999999979

# %% [markdown]
# ## Linear Regression using Gradient Descent

# %% [markdown]
# it will the model reach the lower point or else convergence. convergence help to reach minimum point.
# how does gradient descent help to reach minimum.. model is optimised.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x=np.array([1,2,3,4,5])
y=np.array([2,5,7,10,11])


# initialize parameters
w=0.0
b=0.0

learning_rate=0.01
epochs=1000
n=len(x)

# training 
for i in range(epochs):
    y_pred=w*x+b


    dw=(-2/n)*np.sum(x*(y-y_pred))
    db=(-2/n)*np.sum(y-y_pred)

    w-= learning_rate*dw    #dw is the change 
    b-=learning_rate*db

print("final weights:",w)
print("final bias:",b)


    # plot
y_pred=w*x+b
plt.scatter(x,y)
plt.plot(x,y_pred,color='red')
plt.grid(True)
plt.show()
# Out:
# final weights: 2.295327426439805
# final bias: 0.11686947315186567
