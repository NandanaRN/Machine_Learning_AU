# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.preprocessing import normalize
from sklearn.cluster import AgglomerativeClustering

# %%
df = pd.read_csv("Data/Wholesale customers data.csv")
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
scaled_df = normalize(df)
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)

# %%
plt.figure(figsize=(10, 7))  
plt.title("Dendrogram")  
d = sch.dendrogram(sch.linkage(scaled_df, method='ward'))
plt.axhline(y=3, color='r', linestyle='--')
plt.xlabel("Customer Indices")
plt.ylabel("Euclidean Distances")
plt.show()

# %%
cluster = AgglomerativeClustering(n_clusters=5, metric='euclidean', linkage='ward')  
labels = cluster.fit_predict(scaled_df)

# %%
print("Cluster labels for the first 5 customers:")
print(labels[:5])
# Out:
# Cluster labels for the first 5 customers:
# [1 1 1 0 2]
