# %% [markdown]
# classification algorithm is logistic regression,

# %% [markdown]
# ### 1.probability  :p
# 0-1
# ### 2. odds :p/(1-p)
# 0-Infinity

# %% [markdown]
# Logistic Regression l(0) =sigma(h(0)) where h(0):hypothesis of linear Regression
#
# TL:DR.We feed the line or the equation of line provided by linear regression to the sigmoid/ logistic function to recieve a value between 0 and 1 and represent the probability value
#
# 1.In logistic Regression ,How do we actually find the probabilistic value or how do we make sure that the value provided by the sigmoid function is representing probability ?

# %% [markdown]
# ## statement:logistic Function provides us with probabilistic value
# ## assume: the line in lining actually represents the log(odds) of class probability of a number ; i.e.,$log(p/(p-1))$
#
# so:we have to prove that $\sigma(p/(p-1))$ =$p$
#
# 1.$\sigma(p/(p-1))$
