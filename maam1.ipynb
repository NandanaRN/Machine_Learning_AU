# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import zscore

# %%
data =np.array([48,50,52,54,58,120,130])

# %%
Q1=np.percentile(data,25)
Q3=np.percentile(data,75)

# %%
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR   # fixed

outliers = data[(data < lower_bound) | (data > upper_bound)]

# %%
print(outliers)
# Out:
# []

# %%
plt.figure()
box=plt.boxplot(data)
plt.show()

# %%
z_scores=zscore(data)
outliers_=data[np.abs(z_scores) >3]
outliers_=data[np.abs(z_scores) >2]
print(outliers_)
# Out:
# []

# %% [markdown]
# activity : generate dat afrom chatgpt or kaggle and then do z score or iqr and to find outliers

# %% [markdown]
# 30/1/26
# code of the day

# %%
df=pd.read_csv('people.csv') #load the dataset

# %%
df.head()  #first five values
# Out:
#    id    name   age    salary   join_date       city
# 0   1  Vihaan  23.0   61048.0  2017-09-30     Mumbai
# 1   2   Arjun  28.0  113696.0  2023-04-22    Kolkata
# 2   3  Aditya  59.0   80302.0  2015-05-11      Delhi
# 3   4  Aditya   NaN   55495.0  2020-08-31    Kolkata
# 4   5   Aarav  57.0   51062.0  2023-01-11  Hyderabad

# %%
df.tail()  #last five values
# Out:
#     id     name   age    salary   join_date       city
# 45  46    Aarav  26.0  117778.0  2022-01-28      Delhi
# 46  47  Krishna  26.0   29117.0  2024-08-22  Bangalore
# 47  48   Aditya  54.0   56195.0  2018-02-14  Hyderabad
# 48  49    Meera  35.0   95678.0  2016-06-25  Hyderabad
# 49  50     Myra  58.0   86953.0  2017-09-22    Chennai

# %%
df.info() #summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         50 non-null     int64
#  1   name       50 non-null     object
#  2   age        49 non-null     float64
#  3   salary     49 non-null     float64
#  4   join_date  50 non-null     object
#  5   city       49 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.5+ KB

# %%
df.describe() #statistical summary
# Out:
#               id         age          salary
# count  50.000000   49.000000       49.000000
# mean   25.100000   44.530612    90585.326531
# std    14.938309   15.068043   135305.975881
# min     1.000000   22.000000    25425.000000
# 25%    12.250000   32.000000    53893.000000
# 50%    25.500000   45.000000    67487.000000
# 75%    37.750000   56.000000    95678.000000
# max    50.000000  105.000000  1000000.000000

# %%
df.isnull().sum()  #check for missing values
# Out:
# id           0
# name         0
# age          1
# salary       1
# join_date    0
# city         1
# dtype: int64

# %%
df.isnull().sum().plot(kind='bar')
plt.show()

# %%
df['city']=df['city'].fillna(df['city'].mode()[0])  #filling missing values with mode

# %%
df['city'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['age']=df['age'].fillna(df['age'].mean())  #filling missing values with mean

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['city']=df['city'].fillna(df['city'].mode()[0])  #filling missing values with mode

# %%
df['city'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['salary']=pd.to_numeric(df['salary'],errors='coerce')  #converting to numeric    
df['salary'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df['salary']=df['salary'].fillna(df['salary'].median())  #filling missing values with median

# %%
df['join_date']=pd.to_datetime(df['join_date'],errors='coerce')  #converting to datetime    
df['join_date'].dtype
df['join_date']=df['join_date'].fillna(pd.Timestamp.today())  #filling missing values with current date

# %%
df['age']=pd.to_numeric(df['age'],errors='coerce')  #converting to numeric    
plt.boxplot(df['age'])
plt.show()

# %%
df
# Out:
#     id     name         age     salary   join_date       city
# 0    1   Vihaan   23.000000    61048.0  2017-09-30     Mumbai
# 1    2    Arjun   28.000000   113696.0  2023-04-22    Kolkata
# 2    3   Aditya   59.000000    80302.0  2015-05-11      Delhi
# 3    4   Aditya   44.530612    55495.0  2020-08-31    Kolkata
# 4    5    Aarav   57.000000    51062.0  2023-01-11  Hyderabad
# 5    6      Ira   48.000000    53893.0  2020-01-14    Kolkata
# 6    7   Ishaan   22.000000    45926.0  2022-10-30    Chennai
# 7    8   Ananya   39.000000        NaN  2017-05-31  Bangalore
# 8    9   Vihaan   27.000000    74797.0  2016-02-01  Bangalore
# 9   10     Diya   60.000000    59671.0  2024-01-19      Delhi
# 10   6      Ira   48.000000    53893.0  2020-01-14    Kolkata
# 11  12      Ira   40.000000   107397.0  2021-12-08  Bangalore
# 12  13     Myra   34.000000   117349.0  2015-10-12      Delhi
# 13  14  Krishna   40.000000    35458.0  2024-08-04     Mumbai
# ...
